# %%
#difference between most and least expensive


cost=[850000,25000,1200000,18000,9500]
x=max(cost)-min(cost)
print(x)
# Out:
# 1182000

# %%
y=sum(cost)/len(cost)
print(y)
# Out:
# 374666.6666666667

# %%
#list the equipment more than average cost
cost=[850000,25000,1200000,60000,18000,95000]
for i in range cost:
  if cost[i]>y:
    print(cost[i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2355539372.py in <cell line: 0>()
#       2 cost=[850000,25000,1200000,60000,18000,95000]
#       3 for i in range(len(cost)):
# ----> 4   if cost[i]>y:
#       5     print(cost[i])
#
# NameError: name 'y' is not defined
